# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import scipy.stats

import plotly.io as pio
import plotly.express as px
import plotly.graph_objects as go

#Set working directory
os.chdir('C:/Users/Martin/Documents/GitHub/World-Happiness-Data/Martin_Alvarez-Kuglen')

# %%
df = pd.read_excel("C:/Users/Martin/Documents/GitHub/DataPanelWHR2021C2.xls")
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.370100        0.450662
# 1  Afghanistan  2009     4.401778            7.539972        0.552308
# 2  Afghanistan  2010     4.758381            7.646709        0.539075
# 3  Afghanistan  2011     3.831719            7.619532        0.521104
# 4  Afghanistan  2012     3.782938            7.705479        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.167640
# 1                         51.200001                      0.678896    0.190099
# 2                         51.599998                      0.600127    0.120590
# 3                         51.919998                      0.495901    0.162427
# 4                         52.240002                      0.530935    0.236032
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919

# %%
df.set_index(pd.to_datetime(df['year'], yearfirst=True, format = '%Y'), inplace = True)
df
# Out:
#            Country name  year  Life Ladder  Log GDP per capita  \
# year
# 2008-01-01  Afghanistan  2008     3.723590            7.370100
# 2009-01-01  Afghanistan  2009     4.401778            7.539972
# 2010-01-01  Afghanistan  2010     4.758381            7.646709
# 2011-01-01  Afghanistan  2011     3.831719            7.619532
# 2012-01-01  Afghanistan  2012     3.782938            7.705479
# ...                 ...   ...          ...                 ...
# 2016-01-01     Zimbabwe  2016     3.735400            7.984372
# 2017-01-01     Zimbabwe  2017     3.638300            8.015738
# 2018-01-01     Zimbabwe  2018     3.616480            8.048798
# 2019-01-01     Zimbabwe  2019     2.693523            7.950132
# 2020-01-01     Zimbabwe  2020     3.159802            7.828757
#
#             Social support  Healthy life expectancy at birth  \
# year
# 2008-01-01        0.450662                         50.799999
# 2009-01-01        0.552308                         51.200001
# 2010-01-01        0.539075                         51.599998
# 2011-01-01        0.521104                         51.919998
# 2012-01-01        0.520637                         52.240002
# ...                    ...                               ...
# 2016-01-01        0.768425                         54.400002
# 2017-01-01        0.754147                         55.000000
# 2018-01-01        0.775388                         55.599998
# 2019-01-01        0.759162                         56.200001
# 2020-01-01        0.717243                         56.799999
#
#             Freedom to make life choices  Generosity  \
# year
# 2008-01-01                      0.718114    0.167640
# 2009-01-01                      0.678896    0.190099
# 2010-01-01                      0.600127    0.120590
# 2011-01-01                      0.495901    0.162427
# 2012-01-01                      0.530935    0.236032
# ...                                  ...         ...
# 2016-01-01                      0.732971   -0.094634
# 2017-01-01                      0.752826   -0.097645
# 2018-01-01                      0.762675   -0.068427
# 2019-01-01                      0.631908   -0.063791
# 2020-01-01                      0.643303   -0.008696
#
#             Perceptions of corruption  Positive affect  Negative affect
# year
# 2008-01-01                   0.881686         0.517637         0.258195
# 2009-01-01                   0.850035         0.583926         0.237092
# 2010-01-01                   0.706766         0.618265         0.275324
# 2011-01-01                   0.731109         0.611387         0.267175
# 2012-01-01                   0.775620         0.710385         0.267919
# ...                               ...              ...              ...
# 2016-01-01                   0.723612         0.737636         0.208555
# 2017-01-01                   0.751208         0.806428         0.224051
# 2018-01-01                   0.844209         0.710119         0.211726
# 2019-01-01                   0.830652         0.716004         0.235354
# 2020-01-01                   0.788523         0.702573         0.345736
#
# [1949 rows x 11 columns]

# %%
year_data = pd.Series(dtype = 'int64')
for year in df.index.unique():    
    year_data = year_data.append(pd.Series(df.loc[year]['Country name'].unique().size, index = [year], dtype = 'int64'))
year_data.plot()
# Out:
# <AxesSubplot:>

# %%
variables = ['year','Life Ladder','Log GDP per capita','Social support','Healthy life expectancy at birth',
 'Freedom to make life choices','Generosity','Perceptions of corruption','Positive affect','Negative affect']

corr_table = pd.DataFrame()
for var1 in variables:
    cor = []
    for var2 in variables:
        cor.append(df[var1].corr(df[var2]))
    corr_table[var1] = pd.Series(cor, index = variables)
corr_table
# Out:
#                                       year  Life Ladder  Log GDP per capita  \
# year                              1.000000     0.035515            0.078259
# Life Ladder                       0.035515     1.000000            0.790165
# Log GDP per capita                0.078259     0.790165            1.000000
# Social support                   -0.010064     0.707825            0.692642
# Healthy life expectancy at birth  0.164059     0.744499            0.848053
# Freedom to make life choices      0.222109     0.528095            0.367941
# Generosity                       -0.043374     0.190650           -0.000872
# Perceptions of corruption        -0.081444    -0.427325           -0.345545
# Positive affect                  -0.003127     0.532380            0.302395
# Negative affect                   0.196904    -0.297572           -0.210816
#
#                                   Social support  \
# year                                   -0.010064
# Life Ladder                             0.707825
# Log GDP per capita                      0.692642
# Social support                          1.000000
# Healthy life expectancy at birth        0.616087
# Freedom to make life choices            0.410551
# Generosity                              0.066985
# Perceptions of corruption              -0.219068
# Positive affect                         0.432307
# Negative affect                        -0.395859
#
#                                   Healthy life expectancy at birth  \
# year                                                      0.164059
# Life Ladder                                               0.744499
# Log GDP per capita                                        0.848053
# Social support                                            0.616087
# Healthy life expectancy at birth                          1.000000
# Freedom to make life choices                              0.388679
# Generosity                                                0.020789
# Perceptions of corruption                                -0.322526
# Positive affect                                           0.318364
# Negative affect                                          -0.139513
#
#                                   Freedom to make life choices  Generosity  \
# year                                                  0.222109   -0.043374
# Life Ladder                                           0.528095    0.190650
# Log GDP per capita                                    0.367941   -0.000872
# Social support                                        0.410551    0.066985
# Healthy life expectancy at birth                      0.388679    0.020789
# Freedom to make life choices                          1.000000    0.329385
# Generosity                                            0.329385    1.000000
# Perceptions of corruption                            -0.487898   -0.290806
# Positive affect                                       0.606266    0.358154
# Negative affect                                      -0.267724   -0.092648
#
#                                   Perceptions of corruption  Positive affect  \
# year                                              -0.081444        -0.003127
# Life Ladder                                       -0.427325         0.532380
# Log GDP per capita                                -0.345545         0.302395
# Social support                                    -0.219068         0.432307
# Healthy life expectancy at birth                  -0.322526         0.318364
# Freedom to make life choices                      -0.487898         0.606266
# Generosity                                        -0.290806         0.358154
# Perceptions of corruption                          1.000000        -0.296607
# Positive affect                                   -0.296607         1.000000
# Negative affect                                    0.264274        -0.374458
#
#                                   Negative affect
# year                                     0.196904
# Life Ladder                             -0.297572
# Log GDP per capita                      -0.210816
# Social support                          -0.395859
# Healthy life expectancy at birth        -0.139513
# Freedom to make life choices            -0.267724
# Generosity                              -0.092648
# Perceptions of corruption                0.264274
# Positive affect                         -0.374458
# Negative affect                          1.000000

# %%
fig = px.scatter(df, x = 'Life Ladder' , y= 'Social support', trendline="ols",
                title= "World Happiness Report: General Life Enjoyment Versus Social Support Evaluation",
                labels = {'Life Ladder':'General Life Enjoyment (1-8)', 'Social support':'Social Support Evaluation (0-1)'})
fig.data[1].line.color = 'red'


fig.show()
# Out:
# <div>                            <div id="e060a266-54bc-49ff-9287-15023c5741f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("