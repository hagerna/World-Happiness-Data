# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly
import numpy as np

# %%
# import demographic spreadsheet as an Excel file
df_happiness = pd.read_excel("Neg_Pos_Affect.xls")
# display first 5 rows of demographic data spreadhseet
df_happiness.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.144916        0.450662
# 1  Afghanistan  2009     4.401778            7.314788        0.552308
# 2  Afghanistan  2010     4.758381            7.421525        0.539075
# 3  Afghanistan  2011     3.831719            7.394349        0.521104
# 4  Afghanistan  2012     3.782938            7.480296        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.178993
# 1                         51.200001                      0.678896    0.201228
# 2                         51.599998                      0.600127    0.131578
# 3                         51.919998                      0.495901    0.173452
# 4                         52.240002                      0.530935    0.246943
#
#    Perceptions of corruption  Positive affect  ...  \
# ...

# %%
# Initialize figure
fig = go.Figure()

# Add Traces

fig.add_trace(
    go.Scatter(x=df_happiness["Life Ladder"],
               y=df_happiness["Negative affect"],
               mode='markers',
               name='Negative Affect'))

fig.add_trace(
    go.Scatter(x=df_happiness["Life Ladder"],
               y=df_happiness["Positive affect"],
               mode='markers',
               name='Positive Affect'))

# Set title
fig.update_layout(title_text="Affect and Life Ladder", xaxis_title="Life Ladder",
    yaxis_title="Affect")

plotly.io.write_html(fig,"Affect.html", full_html=False)

fig.show()
# Out:
# <div>                            <div id="eb81a437-f9fd-4ba7-9c44-910ac0b6c199" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb81a437-f9fd-4ba7-9c44-910ac0b6c199")) {                    Plotly.newPlot(                        "eb81a437-f9fd-4ba7-9c44-910ac0b6c199",                        [{"mode": "markers", "name": "Negative Affect", "type": "scatter", "x": [3.7235898971557617, 4.401778221130371, 4.758380889892578, 3.831719160079956, 3.782937526702881, 3.5721004009246826, 3.1308956146240234, 3.9828546047210693, 4.220168590545654, 2.6617181301116943, 2.694303274154663, 2.375091791152954, 4.634251594543457, 5.485469818115234, 5.268936634063721, 5.867421627044678, 5.510124206542969, 4.550647735595703, 4.81376314163208, 4.6066508293151855, 4.51110076
# ...
